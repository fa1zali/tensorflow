# %% [markdown]
# **Importing libraries**

# %%
import tensorflow as tf

# %% [markdown]
# ### Create Tensors

# %%
string = tf.Variable("this is a string", tf.string)
number = tf.Variable(123, tf.int16)
floating = tf.Variable(3.45, tf.float16)

print(string)
print(number)
print(floating)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=string, numpy=b'this is a string'>
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=123>
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=3.45>

# %% [markdown]
# ### Rank/Degree of Tensor

# %%
rank1_tensor = tf.Variable(["this is a string"], tf.string)
print(rank1_tensor)

rank2_tensor = tf.Variable([["this is a string", "ok"],\
                            ["this is also a string","yes"]], tf.string)
print(rank2_tensor)
# Out:
# <tf.Variable 'Variable:0' shape=(1,) dtype=string, numpy=array([b'this is a string'], dtype=object)>
# <tf.Variable 'Variable:0' shape=(2, 2) dtype=string, numpy=
# array([[b'this is a string', b'ok'],
#        [b'this is also a string', b'yes']], dtype=object)>

# %%
tf.rank(rank1_tensor)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=1>

# %%
tf.rank(rank2_tensor)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=2>

# %%
tf.rank(number)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=0>

# %%
tf.rank(tf.Variable([["Yes"],["No"]], tf.string))
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=2>

# %% [markdown]
# ### Shape of Tensor

# %%
string.shape, number.shape, floating.shape
# Out:
# (TensorShape([]), TensorShape([]), TensorShape([]))

# %%
rank1_tensor.shape, rank2_tensor.shape
# Out:
# (TensorShape([1]), TensorShape([2, 2]))

# %%
(tf.Variable([["Yes"],["No"]], tf.string)).shape
# Out:
# TensorShape([2, 1])

# %% [markdown]
# ### Reshape

# %%
tensor1 = tf.ones([1,2], tf.int16)
print(tensor1)
# Out:
# tf.Tensor([[1 1]], shape=(1, 2), dtype=int16)

# %%
tensor2 = tf.reshape(tensor1, [2,1])
print(tensor2)
# Out:
# tf.Tensor(
# [[1]
#  [1]], shape=(2, 1), dtype=int16)
